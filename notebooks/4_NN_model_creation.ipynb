# %%
import pandas as pd
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset, random_split
from sklearn.model_selection import train_test_split

# %%
RANDOM_SEED = 42
random_generator = torch.Generator().manual_seed(RANDOM_SEED)

# %%
device = "mps" if torch.backends.mps.is_available() else "cpu"

device
# Out:
# 'mps'

# %%
df = pd.read_parquet('../data/processed/1_train_processed.parquet')

df
# Out:
#               id     sales  onpromotion  transactions  dcoilwtico  pay_day  \
# 0              0     0.000     0.000000      0.202538    0.492910    False
# 1              1     0.000     0.000000      0.202538    0.492910    False
# 2              2     0.000     0.000000      0.202538    0.492910    False
# 3              3     0.000     0.000000      0.202538    0.492910    False
# 4              4     0.000     0.000000      0.202538    0.492910    False
# ...          ...       ...          ...           ...         ...      ...
# 3054343  3000883   438.133     0.000000      0.257362    0.253228     True
# 3054344  3000884   154.553     0.001350      0.257362    0.253228     True
# 3054345  3000885  2419.729     0.199730      0.257362    0.253228     True
# 3054346  3000886   121.000     0.010796      0.257362    0.253228     True
# 3054347  3000887    16.000     0.000000      0.257362    0.253228     True
#
#          store_nbr_1  store_nbr_2  store_nbr_3  store_nbr_4  ...  month_2  \
# 0               True        False        False        False  ...    False
# 1               True        False        False        False  ...    False
# 2               True        False        False        False  ...    False
# 3               True        False        False        False  ...    False
# 4               True        False        False        False  ...    False
# ...              ...          ...          ...          ...  ...      ...
# 3054343        False        False        False        False  ...    False
# 3054344        False        False        False        False  ...    False
# 3054345        False        False        False        False  ...    False
# 3054346        False        False        False        False  ...    False
# 3054347        False        False        False        False  ...    False
#
#          month_3  month_4  month_5  month_6  month_7  month_8  month_9  \
# 0          False    False    False    False    False    False    False
# 1          False    False    False    False    False    False    False
# 2          False    False    False    False    False    False    False
# 3          False    False    False    False    False    False    False
# 4          False    False    False    False    False    False    False
# ...          ...      ...      ...      ...      ...      ...      ...
# 3054343    False    False    False    False    False     True    False
# 3054344    False    False    False    False    False     True    False
# 3054345    False    False    False    False    False     True    False
# 3054346    False    False    False    False    False     True    False
# 3054347    False    False    False    False    False     True    False
#
#          month_10  month_11
# 0           False     False
# 1           False     False
# 2           False     False
# 3           False     False
# 4           False     False
# ...           ...       ...
# 3054343     False     False
# 3054344     False     False
# 3054345     False     False
# 3054346     False     False
# 3054347     False     False
#
# [3054348 rows x 191 columns]

# %%
df['is_zero'] = (df.sales == 0).astype('float32')

df
# Out:
#               id     sales  onpromotion  transactions  dcoilwtico  pay_day  \
# 0              0     0.000     0.000000      0.202538    0.492910    False
# 1              1     0.000     0.000000      0.202538    0.492910    False
# 2              2     0.000     0.000000      0.202538    0.492910    False
# 3              3     0.000     0.000000      0.202538    0.492910    False
# 4              4     0.000     0.000000      0.202538    0.492910    False
# ...          ...       ...          ...           ...         ...      ...
# 3054343  3000883   438.133     0.000000      0.257362    0.253228     True
# 3054344  3000884   154.553     0.001350      0.257362    0.253228     True
# 3054345  3000885  2419.729     0.199730      0.257362    0.253228     True
# 3054346  3000886   121.000     0.010796      0.257362    0.253228     True
# 3054347  3000887    16.000     0.000000      0.257362    0.253228     True
#
#          store_nbr_1  store_nbr_2  store_nbr_3  store_nbr_4  ...  month_3  \
# 0               True        False        False        False  ...    False
# 1               True        False        False        False  ...    False
# 2               True        False        False        False  ...    False
# 3               True        False        False        False  ...    False
# 4               True        False        False        False  ...    False
# ...              ...          ...          ...          ...  ...      ...
# 3054343        False        False        False        False  ...    False
# 3054344        False        False        False        False  ...    False
# 3054345        False        False        False        False  ...    False
# 3054346        False        False        False        False  ...    False
# 3054347        False        False        False        False  ...    False
#
#          month_4  month_5  month_6  month_7  month_8  month_9  month_10  \
# 0          False    False    False    False    False    False     False
# 1          False    False    False    False    False    False     False
# 2          False    False    False    False    False    False     False
# 3          False    False    False    False    False    False     False
# 4          False    False    False    False    False    False     False
# ...          ...      ...      ...      ...      ...      ...       ...
# 3054343    False    False    False    False     True    False     False
# 3054344    False    False    False    False     True    False     False
# 3054345    False    False    False    False     True    False     False
# 3054346    False    False    False    False     True    False     False
# 3054347    False    False    False    False     True    False     False
#
#          month_11  is_zero
# 0           False      1.0
# 1           False      1.0
# 2           False      1.0
# 3           False      1.0
# 4           False      1.0
# ...           ...      ...
# 3054343     False      0.0
# 3054344     False      0.0
# 3054345     False      0.0
# 3054346     False      0.0
# 3054347     False      0.0
#
# [3054348 rows x 192 columns]

# %%
df.shape
# Out:
# (3054348, 192)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3054348 entries, 0 to 3054347
# Columns: 192 entries, id to is_zero
# dtypes: bool(186), float32(1), float64(4), uint32(1)
# memory usage: 658.3 MB

# %%
# df = df.head(1_000_000)

# %%
df = df.astype('float32')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3054348 entries, 0 to 3054347
# Columns: 192 entries, id to is_zero
# dtypes: float32(192)
# memory usage: 2.2 GB

# %%
X = df.drop(columns=['id', 'sales', 'is_zero'])
y_is_zero = df['is_zero']
y_sales = df['sales']

X.shape, y_is_zero.shape, y_sales.shape
# Out:
# ((3054348, 189), (3054348,), (3054348,))

# %%
# X_tensor = torch.tensor(X.to_numpy(), dtype=torch.float32, device=device)
# y_is_zero_tensor = torch.tensor(y_is_zero.to_numpy(), dtype=torch.float32, device=device)
# y_sales_tensor = torch.tensor(y_sales.to_numpy(), dtype=torch.float32, device=device)

# X_tensor.shape, y_is_zero_tensor.shape, y_sales_tensor.shape

# %%
class SalesPredictor(nn.Module):
    def __init__(self):
        super(SalesPredictor, self).__init__()
        self.shared_layers = nn.Sequential(
            nn.Linear(X.shape[1], 128),
            nn.ReLU(),
            nn.Dropout(p=0.3),
            nn.Linear(128, 64),
            nn.ReLU()
        )
        # self.classification_layers = nn.Sequential(
        #     nn.Linear(64, 32),
        #     nn.ReLU(),
        #     nn.Linear(32, 1),
        #     nn.Sigmoid()
        # )
        self.regression_layers = nn.Sequential(
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1)
        )
    def forward(self, x):
        shared_layers = self.shared_layers(x)
        # is_zero = self.classification_layers(shared_layers)
        sales = self.regression_layers(shared_layers)
        return sales

# %%
X_train, X_test, y_is_zero_train, y_is_zero_test, y_sales_train, y_sales_test = train_test_split(
    X, y_is_zero, y_sales, test_size=0.2, random_state=RANDOM_SEED
)

X_train.shape, X_test.shape, y_is_zero_train.shape, y_is_zero_test.shape, y_sales_train.shape, y_sales_test.shape
# Out:
# ((2443478, 189), (610870, 189), (2443478,), (610870,), (2443478,), (610870,))

# %%
X_train_tensor = torch.tensor(X_train.to_numpy(), dtype=torch.float32, device=device)
X_test_tensor = torch.tensor(X_test.to_numpy(), dtype=torch.float32, device=device)
y_is_zero_train_tensor = torch.tensor(y_is_zero_train.to_numpy(), dtype=torch.float32, device=device)
y_is_zero_test_tensor = torch.tensor(y_is_zero_test.to_numpy(), dtype=torch.float32, device=device)
y_sales_train_tensor = torch.tensor(y_sales_train.to_numpy(), dtype=torch.float32, device=device)
y_sales_test_tensor = torch.tensor(y_sales_test.to_numpy(), dtype=torch.float32, device=device)

print(f"""{X_train_tensor.shape = }, {X_test_tensor.shape = }, {y_is_zero_train_tensor.shape = }, 
      {y_is_zero_test_tensor.shape = }, {y_sales_train_tensor.shape = }, {y_sales_test_tensor.shape = }""")
# Out:
# X_train_tensor.shape = torch.Size([2443478, 189]), X_test_tensor.shape = torch.Size([610870, 189]), y_is_zero_train_tensor.shape = torch.Size([2443478]),
#       y_is_zero_test_tensor.shape = torch.Size([610870]), y_sales_train_tensor.shape = torch.Size([2443478]), y_sales_test_tensor.shape = torch.Size([610870])

# %%
# ds = TensorDataset(X_tensor, y_is_zero_tensor, y_sales_tensor)

# train_size = int(0.8 * len(ds))
# test_size = int(len(ds) - train_size)
# train_ds, test_ds = random_split(dataset=ds, lengths=[train_size, test_size], generator=random_generator)

# train_ds, test_ds

# %%
# BATCH_SIZE = 128

# %%
# train_dataloader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, generator=random_generator)
# test_dataloader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False, generator=random_generator)

# %%
# f"number of batches = {X.shape[0] / BATCH_SIZE}"

# %%
torch.manual_seed(RANDOM_SEED)
model = SalesPredictor()

model.to(device)

model, model.state_dict(), next(model.parameters()).device
# Out:
# (SalesPredictor(
#    (shared_layers): Sequential(
#      (0): Linear(in_features=189, out_features=128, bias=True)
#      (1): ReLU()
#      (2): Dropout(p=0.3, inplace=False)
#      (3): Linear(in_features=128, out_features=64, bias=True)
#      (4): ReLU()
#    )
#    (regression_layers): Sequential(
#      (0): Linear(in_features=64, out_features=32, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=32, out_features=1, bias=True)
#    )
#  ),
#  OrderedDict([('shared_layers.0.weight',
#                tensor([[ 0.0556,  0.0604, -0.0170,  ...,  0.0272, -0.0128, -0.0193],
#                        [ 0.0078, -0.0128, -0.0217,  ..., -0.0351,  0.0132,  0.0396],
#                        [ 0.0603, -0.0668,  0.0486,  ..., -0.0510, -0.0452, -0.0641],
#                        ...,
#                        [-0.0552, -0.0163,  0.0682,  ...,  0.0524,  0.0248, -0.0716],
#                        [-0.0238, -0.0373, -0.0655,  ...,  0.0004, -0.0089, -0.0017],
#                        [-0.0616, -0.0674, -0.0266,  ...,  0.0363,  0.0359, -0.0160]],
#                       device='mps:0')),
#               ('shared_layers.0.bias',
#                tensor([-0.0196, -0.0708, -0.0004, -0.0164, -0.0525,  0.0358,  0.0445,  0.0216,
#                        -0.0499, -0.0174, -0.0632, -0.0118,  0.0348,  0.0574, -0.0592, -0.0147,
#                        -0.0356,  0.0525,  0.0693, -0.0645, -0.0310,  0.0025, -0.0651, -0.0684,
#                        -0.0440,  0.0533,  0.0151, -0.0344, -0.0103,  0.0667, -0.0688,  0.0285,
#                        -0.0025, -0.0703,  0.0633, -0.0336,  0.0547,  0.0054,  0.0167, -0.0105,
#                        -0.0586,  0.0364, -0.0250,  0.0273,  0.0686, -0.0210,  0.0086,  0.0255,
#                        -0.0229,  0.0336, -0.0456,  0.0441, -0.0274, -0.0012, -0.0249,  0.0079,
#                         0.0512,  0.0144, -0.0255,  0.0683,  0.0662, -0.0302, -0.0432, -0.0515,
#                         0.0127,  0.0680,  0.0231,  0.0268, -0.0687,  0.0292,  0.0390, -0.0223,
#                        -0.0453, -0.0088, -0.0626,  0.0669, -0.0441,  0.0655, -0.0722,  0.0464,
#                        -0.0304, -0.0560,  0.0205,  0.0670, -0.0347,  0.0102, -0.0476,  0.0474,
#                         0.0655, -0.0198,  0.0697,  0.0376,  0.0098, -0.0313,  0.0502,  0.0037,
#                        -0.0308, -0.0716, -0.0705,  0.0725, -0.0384, -0.0543,  0.0461, -0.0208,
#                        -0.0542,  0.0147, -0.0108,  0.0281,  0.0676, -0.0183,  0.0414, -0.0203,
#                        -0.0240,  0.0243, -0.0163,  0.0195,  0.0162, -0.0583, -0.0170,  0.0656,
#                        -0.0004,  0.0690,  0.0550, -0.0204, -0.0329,  0.0240, -0.0120, -0.0094],
#                       device='mps:0')),
#               ('shared_layers.3.weight',
#                tensor([[-0.0060, -0.0571,  0.0556,  ...,  0.0306, -0.0486, -0.0807],
#                        [ 0.0711, -0.0746, -0.0377,  ...,  0.0394,  0.0647,  0.0494],
#                        [ 0.0594, -0.0534,  0.0754,  ...,  0.0118,  0.0638,  0.0550],
#                        ...,
#                        [ 0.0290, -0.0542, -0.0426,  ..., -0.0135, -0.0133,  0.0509],
#                        [ 0.0145, -0.0816,  0.0866,  ...,  0.0476,  0.0387, -0.0502],
#                        [ 0.0128, -0.0131,  0.0445,  ..., -0.0129, -0.0817,  0.0297]],
#                       device='mps:0')),
#               ('shared_layers.3.bias',
#                tensor([ 0.0104, -0.0690, -0.0199,  0.0310, -0.0559,  0.0357, -0.0641,  0.0047,
#                        -0.0118, -0.0651, -0.0141, -0.0420, -0.0159,  0.0101, -0.0140, -0.0100,
#                         0.0707,  0.0682, -0.0457,  0.0117,  0.0332,  0.0059,  0.0069, -0.0339,
#                         0.0161, -0.0513, -0.0188, -0.0388,  0.0302,  0.0308, -0.0757, -0.0697,
#                         0.0017,  0.0266, -0.0847,  0.0069, -0.0528, -0.0763,  0.0775, -0.0567,
#                        -0.0422,  0.0854, -0.0529, -0.0360, -0.0534, -0.0464,  0.0104,  0.0461,
#                         0.0289, -0.0255,  0.0234, -0.0650,  0.0665, -0.0632,  0.0406, -0.0682,
#                        -0.0376, -0.0804,  0.0132,  0.0439, -0.0613,  0.0325, -0.0206,  0.0183],
#                       device='mps:0')),
#               ('regression_layers.0.weight',
#                tensor([[-0.0854, -0.0926, -0.0182,  ..., -0.0546, -0.0771, -0.0337],
#                        [-0.0581,  0.1128, -0.0916,  ..., -0.0225, -0.0231,  0.0473],
#                        [-0.0166,  0.1148,  0.0015,  ..., -0.0911, -0.0861,  0.1193],
#                        ...,
#                        [ 0.1049, -0.0393,  0.0463,  ...,  0.0862,  0.0582,  0.0818],
#                        [ 0.0975,  0.0432, -0.0823,  ..., -0.1130,  0.0580,  0.0855],
#                        [-0.0771,  0.0270, -0.0595,  ...,  0.0552, -0.0162,  0.0071]],
#                       device='mps:0')),
#               ('regression_layers.0.bias',
#                tensor([ 0.1128,  0.0488,  0.0043,  0.0883, -0.0233, -0.0614,  0.0449, -0.0945,
#                         0.0370,  0.0535,  0.0684,  0.0215,  0.0825,  0.0796,  0.0679, -0.0922,
#                         0.0230,  0.0605,  0.1021,  0.1109, -0.1157,  0.1075,  0.0304, -0.0687,
#                        -0.1095,  0.0468,  0.0960,  0.0882,  0.0699, -0.0985, -0.1183, -0.0260],
#                       device='mps:0')),
#               ('regression_layers.2.weight',
#                tensor([[-0.0852, -0.1117, -0.1600,  0.0625,  0.0552,  0.0814, -0.0968, -0.1074,
#                          0.0067,  0.1026,  0.0758,  0.0567, -0.0478,  0.0358, -0.0586,  0.1160,
#                          0.1313,  0.0092, -0.0171,  0.1581, -0.1187, -0.0028,  0.0291, -0.0590,
#                         -0.0049, -0.1120,  0.0060,  0.0929,  0.1209,  0.1301,  0.0760,  0.1656]],
#                       device='mps:0')),
#               ('regression_layers.2.bias', tensor([0.0883], device='mps:0'))]),
#  device(type='mps', index=0))

# %%
LEARNING_RATE = 0.01

# %%
loss_clf_fn = nn.BCELoss()
loss_reg_fn = nn.L1Loss()
optimizer = torch.optim.Adam(params=model.parameters(), lr=LEARNING_RATE)

# %%
def accuracy_fn(true_labels, pred_labels):
    correct = torch.eq(true_labels, pred_labels).sum().item()
    acc = (correct/len(pred_labels)) * 100
    return acc

# %%
# is_zero_pred, sales_pred = model(X_train_tensor)
# is_zero_pred = torch.round(is_zero_pred).squeeze()

# is_zero_pred.shape, y_is_zero_train_tensor.shape

# %%
y_sales_train_tensor.shape
# Out:
# torch.Size([2443478])

# %%
# is_zero_pred, sales_pred = model(X_train_tensor)

# is_zero_pred[0]

# %%
# torch.round(is_zero_pred[0])

# %%
torch.manual_seed(RANDOM_SEED)
EPOCHS = 100

for epoch in range(EPOCHS):

    model.train()
    sales_pred = model(X_train_tensor)

    # is_zero_pred = is_zero_pred.squeeze()
    sales_pred = sales_pred.squeeze()
    # loss_clf = loss_clf_fn(is_zero_pred, y_is_zero_train_tensor)
    # acc = accuracy_fn(true_labels=y_is_zero_train_tensor, pred_labels=torch.round(is_zero_pred))

    # 'y_sales' where 'y_is_zero' == 0
    # 'sales_pred' with only the rows from 'y_sales'

    # mask = (y_is_zero_train_tensor == 0).cpu().numpy()

    # print(f"Shape of sales_pred: {sales_pred.shape}")
    # print(f"Shape of y_sales_train_tensor: {y_sales_train_tensor.shape}")
    # print(f"Shape of mask: {mask.shape}")

    # sales_pred = sales_pred[mask]
    # y_sales_train_tensor = y_sales_train_tensor[mask]

    loss = loss_reg_fn(sales_pred, y_sales_train_tensor)

    # loss = loss_clf + loss_reg

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # if (epoch + 1) % 10 == 0:
    #     print(f"{loss_clf = :.2f}, {acc = :.2f}, {loss_reg = :.2f}, {mape = :.2f}")

    if (epoch + 1) % 10 == 0:
        print(f"{loss = :.2f}")
# Out:
# loss = 355.65
# loss = 337.10
# loss = 285.77
# loss = 229.60
# loss = 169.29
# loss = 142.67
# loss = 133.67
# loss = 128.13
# loss = 124.38
# loss = 121.36
